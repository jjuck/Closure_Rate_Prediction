# %%
import pandas as pd

data1 = pd.read_csv('서울시_상권분석서비스(점포-상권)_2022년.csv')
data2 = pd.read_csv('서울시 상권분석서비스(길단위인구-상권).csv')
data3 = pd.read_csv('서울시_상권분석서비스(추정매출-상권)_2022년.csv')

# %%
data1.isna().sum().sum()
# Out:
# 0

# %%
data3.isna().sum().sum()
# Out:
# 0

# %%
data2.drop(columns=['남성_유동인구_수', '여성_유동인구_수', '연령대_10_유동인구_수', '연령대_20_유동인구_수', 
                    '연령대_30_유동인구_수', '연령대_40_유동인구_수', '연령대_50_유동인구_수', '연령대_60_이상_유동인구_수', 
                    '시간대_00_06_유동인구_수', '시간대_06_11_유동인구_수', '시간대_11_14_유동인구_수', '시간대_14_17_유동인구_수', 
                    '시간대_17_21_유동인구_수', '시간대_21_24_유동인구_수', '월요일_유동인구_수', '화요일_유동인구_수', 
                    '수요일_유동인구_수', '목요일_유동인구_수', '금요일_유동인구_수', '토요일_유동인구_수', '일요일_유동인구_수'], inplace=True)
data3.drop(columns=["당월_매출_건수","주중_매출_금액","주말_매출_금액","월요일_매출_금액",
                    "화요일_매출_금액","수요일_매출_금액","목요일_매출_금액","금요일_매출_금액",
                    "토요일_매출_금액","일요일_매출_금액","시간대_00~06_매출_금액","시간대_06~11_매출_금액",
                    "시간대_11~14_매출_금액","시간대_14~17_매출_금액","시간대_17~21_매출_금액","시간대_21~24_매출_금액",
                    "남성_매출_금액","여성_매출_금액","연령대_10_매출_금액","연령대_20_매출_금액",
                    "연령대_30_매출_금액","연령대_40_매출_금액","연령대_50_매출_금액","연령대_60_이상_매출_금액",
                    "주중_매출_건수","주말_매출_건수","월요일_매출_건수","화요일_매출_건수",
                    "수요일_매출_건수","목요일_매출_건수","금요일_매출_건수","토요일_매출_건수",
                    "일요일_매출_건수","시간대_건수~06_매출_건수","시간대_건수~11_매출_건수","시간대_건수~14_매출_건수",
                    "시간대_건수~17_매출_건수","시간대_건수~21_매출_건수","시간대_건수~24_매출_건수","남성_매출_건수",
                    "여성_매출_건수","연령대_10_매출_건수","연령대_20_매출_건수","연령대_30_매출_건수",
                    "연령대_40_매출_건수","연령대_50_매출_건수","연령대_60_이상_매출_건수"], inplace=True)

# %%
merged_df = pd.merge(data1, data2, on=['기준_년분기_코드', '상권_구분_코드', '상권_구분_코드_명', '상권_코드', '상권_코드_명'])
merged_df2 = pd.merge(merged_df, data3, on=['기준_년분기_코드', '상권_구분_코드', '상권_구분_코드_명', '상권_코드', '상권_코드_명', '서비스_업종_코드', '서비스_업종_코드_명'])

# %%
merged_df2
# Out:
#        기준_년분기_코드 상권_구분_코드 상권_구분_코드_명    상권_코드       상권_코드_명  서비스_업종_코드  \
# 0          20221        D       발달상권  3120143           당산역     200001
# 1          20221        D       발달상권  3120143           당산역     300018
# 2          20221        D       발달상권  3120143           당산역     200030
# 3          20221        D       발달상권  3120143           당산역     200025
# 4          20221        D       발달상권  3120143           당산역     300002
# ...          ...      ...        ...      ...           ...        ...
# 83347      20224        R       전통시장  3130286  신신림시장(삼성동시장)     300010
# 83348      20224        A       골목상권  3110959         신구중학교     100001
# 83349      20224        A       골목상권  3110959         신구중학교     200006
# 83350      20224        R       전통시장  3130093          동서시장     300009
# 83351      20224        R       전통시장  3130013       동대문상가A동     300014
#
#       서비스_업종_코드_명  점포_수  유사_업종_점포_수  개업_율  개업_점포_수  폐업_률  폐업_점포_수  프랜차이즈_점포_수  \
# ...

# %%
df_drop = merged_df.drop(columns=['상권_구분_코드_명', '상권_코드_명', '서비스_업종_코드_명', '폐업_점포_수', '폐업_률'])
target = merged_df[['폐업_률']]
df_drop2 = merged_df2.drop(columns=['상권_구분_코드_명', '상권_코드_명', '서비스_업종_코드_명', '폐업_점포_수', '폐업_률'])
target2 = merged_df2[['폐업_률']]

# %%
df_drop2
# Out:
#        기준_년분기_코드 상권_구분_코드    상권_코드  서비스_업종_코드  점포_수  유사_업종_점포_수  개업_율  \
# 0          20221        D  3120143     200001     6           6     0
# 1          20221        D  3120143     300018     9          10    10
# 2          20221        D  3120143     200030    13          14     0
# 3          20221        D  3120143     200025     3           3     0
# 4          20221        D  3120143     300002     1          21    10
# ...          ...      ...      ...        ...   ...         ...   ...
# 83347      20224        R  3130286     300010     3           3     0
# 83348      20224        A  3110959     100001     4           4     0
# 83349      20224        A  3110959     200006     3           3     0
# 83350      20224        R  3130093     300009    62          62     0
# 83351      20224        R  3130013     300014    22          22     0
#
#        개업_점포_수  프랜차이즈_점포_수  총_유동인구_수     당월_매출_금액
# 0            0           0   1067248    241081194
# ...

# %%
import matplotlib.pyplot as plt

plt.plot(df_drop2['당월_매출_금액'])

# %%
import seaborn as sns

sns.kdeplot(df_drop2[['당월_매출_금액']])
# Out:
# <Axes: ylabel='Density'>
# C:\Users\USER\AppData\Roaming\Python\Python311\site-packages\IPython\core\events.py:93: UserWarning: Glyph 45817 (\N{HANGUL SYLLABLE DANG}) missing from current font.
#   func(*args, **kwargs)
# C:\Users\USER\AppData\Roaming\Python\Python311\site-packages\IPython\core\events.py:93: UserWarning: Glyph 50900 (\N{HANGUL SYLLABLE WEOL}) missing from current font.
#   func(*args, **kwargs)
# C:\Users\USER\AppData\Roaming\Python\Python311\site-packages\IPython\core\events.py:93: UserWarning: Glyph 47588 (\N{HANGUL SYLLABLE MAE}) missing from current font.
#   func(*args, **kwargs)
# C:\Users\USER\AppData\Roaming\Python\Python311\site-packages\IPython\core\events.py:93: UserWarning: Glyph 52636 (\N{HANGUL SYLLABLE CUL}) missing from current font.
#   func(*args, **kwargs)
# C:\Users\USER\AppData\Roaming\Python\Python311\site-packages\IPython\core\events.py:93: UserWarning: Glyph 44552 (\N{HANGUL SYLLABLE GEUM}) missing from current font.
#   func(*args, **kwargs)
# ...
